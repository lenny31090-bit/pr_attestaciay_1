# %%
# %mamba install pandas
# Out:
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 4.904 seconds
#   Name           Version  Build                Channel
# --------------------------------------------------------------------
# + pandas         3.0.5    np23py313h1e705a5_0  emscripten-forge-4x
# + python-tzdata  2026.3   pyhd8ed1ab_0         conda-forge
# - pip            26.2.1   pyh145f28c_0         conda-forge

# %%
import pandas
df = pandas.read_csv(r'user_churn_data_ver2.csv')
df
# Out:
#       user_id  days_since_last_session  total_sessions_count  \
# 0           1                        8                    17
# 1           2                      999                     0
# 2           3                        3                     3
# 3           4                      103                     2
# 4           5                       36                     2
# ...       ...                      ...                   ...
# 9995     9996                        4                     2
# 9996     9997                      127                     1
# 9997     9998                       54                    20
# 9998     9999                        7                     6
# 9999    10000                       35                     7
#
#       total_orders_count  total_duration_minutes  is_churned
# 0                      2                     811           0
# 1                      0                       0           1
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  10000 non-null  int64
#  1   days_since_last_session  10000 non-null  int64
#  2   total_sessions_count     10000 non-null  int64
#  3   total_orders_count       10000 non-null  int64
#  4   total_duration_minutes   10000 non-null  int64
#  5   is_churned               10000 non-null  int64
# dtypes: int64(6)
# memory usage: 468.8 KB

# %%
df.describe()
# Out:
#            user_id  days_since_last_session  total_sessions_count  \
# count  10000.00000              10000.00000          10000.000000
# mean    5000.50000                 92.82180              6.499100
# std     2886.89568                231.23504              6.202132
# min        1.00000                  0.00000              0.000000
# 25%     2500.75000                  6.00000              2.000000
# 50%     5000.50000                 19.00000              5.000000
# 75%     7500.25000                 54.00000              9.000000
# max    10000.00000                999.00000             38.000000
#
#        total_orders_count  total_duration_minutes    is_churned
# count         10000.00000            10000.000000  10000.000000
# mean              0.82700              816.685700      0.378500
# std               2.43587             2518.904504      0.485037
# min               0.00000                0.000000      0.000000
# ...

# %%
# Сгруппируем данные по оттоку и рассчитаем среднее количество сессий, после выведем график
sessions_plot = df.groupby('is_churned')['total_sessions_count'].mean()
sessions_plot.plot(kind='bar', color=['skyblue', 'salmon'])
# Out:
# <Axes: xlabel='is_churned'>

# %%
orders_plot = df.groupby('is_churned')['total_orders_count'].mean()
orders_plot.plot(kind='bar', color=['lightgreen', 'coral'])
# Out:
# <Axes: xlabel='is_churned'>

# %%
duration_plot = df.groupby("is_churned")["total_duration_minutes"].mean()

# %%
duration_plot.plot(
    kind="bar", color=["green", "orange"], rot=0, figsize=(8, 5)
)
# Out:
# <Axes: xlabel='is_churned'>
